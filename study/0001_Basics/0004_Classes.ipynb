# %% [markdown]
# ### Creating object function
# __init__()

# %%
class test:
  def __init__(hi, number, letter):
    hi.number = number
    hi.letter = letter

t1 = test(2, "B")

print(t1.number)
print(t1.letter)
# Out:
# 2
# B
